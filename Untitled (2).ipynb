# %%
from AgentBasedModel import *
from AgentBasedModel.extra import *
from AgentBasedModel.visualization import (
    plot_price,
    plot_price_fundamental
)
from random import randint

# Define parameters|
risk_free_rate = 5e-4
price = 100
dividend = price * risk_free_rate

# Initialize objects
assets = [
    Stock(dividend) for _ in range(3)
]
exchanges = [
    ExchangeAgent(assets[0], risk_free_rate) for i in range(3)  # single asset
]
traders = [
    *[Random(exchanges[randint(0, 2)])         for _ in range(5)],
    *[Fundamentalist(exchanges[randint(0, 2)]) for _ in range(5)],
    *[Chartist2D(exchanges)                    for _ in range(5)],
    *[MarketMaker2D(exchanges)                 for _ in range(5)]
]

# Run simulation
simulator = Simulator(**{
    'assets': assets,
    'exchanges': exchanges,
    'traders': traders,
    'events': []
    #[MarketPriceShock(0, 200, -10)]
})

info = simulator.info
simulator.simulate(500, silent=False)


# plot_price(info, None, rolling=1)
# Out:
# Simulation: 100%|██████████| 500/500 [00:01<00:00, 359.02it/s]

# %%
import pandas as pd

# %%
pd.DataFrame(info.trades_history[0])
# Out:
#                                                      0  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    {'qty': 1, 'price': 99.90000000000009, 'side':...
# 4    {'qty': 2, 'price': 100.09999999999997, 'side'...
# ..                                                 ...
# 495                                               None
# 496  {'qty': 3, 'price': 92.39999999999993, 'side':...
# 497                                               None
# 498                                               None
# 499  {'qty': 2, 'price': 92.40000000000009, 'side':...
#
#                                                      1     2     3     4
# 0                                                 None  None  None  None
# 1                                                 None  None  None  None
# 2                                                 None  None  None  None
# 3                                                 None  None  None  None
# 4    {'qty': 5, 'price': 100.16, 'side': 'buy', 'ty...  None  None  None
# ..                                                 ...   ...   ...   ...
# 495                                               None  None  None  None
# 496                                               None  None  None  None
# 497                                               None  None  None  None
# 498                                               None  None  None  None
# 499  {'qty': 4, 'price': 92.39999999999998, 'side':...  None  None  None
#
# [500 rows x 5 columns]

# %% [markdown]
# # Bid-Ask spread

# %%
from AgentBasedModel.model.features import BidAskSpread
bid_ask_spread = BidAskSpread(info)
bid_ask_spread.get_feature_name()
# Out:
# 'bid ask spread'

# %% [markdown]
# # Bid Ask Volume Imbalance

# %%
from AgentBasedModel.model.features import BidAskVolumeImbalance
bid_ask_volume_imbalance = BidAskVolumeImbalance(info, depth = 1)
bid_ask_volume_imbalance.get_feature_name()
# Out:
# 'bid ask volume imbalance at depth 1'

# %% [markdown]
# # Trade Imbalance

# %%
from AgentBasedModel.model.features import TradeVolumeImbalance
trade_volume_imbalance = TradeVolumeImbalance(info, n_iter = 10)
trade_volume_imbalance.get_feature_name()
# Out:
# 'trade imbalance of 10 previous iterations'

# %% [markdown]
# # Plot Feature

# %%
from AgentBasedModel.model.features import BidAskSpread
from AgentBasedModel.model.features import BidAskVolumeImbalance
from AgentBasedModel.model.features import TradeVolumeImbalance

bid_ask_spread = BidAskSpread(info)
bid_ask_volume_imbalance = BidAskVolumeImbalance(info, depth = 1)
trade_volume_imbalance = TradeVolumeImbalance(info, n_iter = 20)

# %%
trade_volume_imbalance.compile_feature()
# Out:
# {0: [0,
#   0,
#   0,
#   0,
#   -1,
#   6,
#   4,
#   4,
#   0,
#   0,
#   -2,
#   -2,
#   -2,
#   -12,
#   -10,
#   -20,
#   -19,
#   -7,
#   26,
#   26,
#   40,
#   40,
#   45,
#   46,
#   50,
#   43,
#   46,
#   50,
#   52,
#   52,
#   54,
#   54,
#   54,
#   67,
#   66,
#   76,
#   73,
#   64,
#   28,
#   30,
#   11,
#   11,
#   8,
#   7,
#   4,
#   7,
#   28,
#   45,
#   47,
#   45,
#   45,
#   44,
#   42,
#   39,
#   38,
#   37,
#   41,
#   38,
#   43,
#   41,
#   46,
#   51,
#   53,
#   53,
#   55,
#   53,
#   40,
#   21,
#   21,
#   24,
#   29,
#   30,
#   32,
#   34,
#   34,
#   30,
#   32,
#   32,
#   36,
#   39,
#   36,
#   35,
#   31,
#   36,
#   34,
#   29,
#   20,
#   18,
#   18,
#   16,
#   11,
#   11,
#   11,
#   9,
#   7,
#   12,
#   5,
#   1,
#   -13,
#   -16,
#   -16,
#   -20,
#   -28,
#   -57,
#   -61,
#   -80,
#   -80,
#   -80,
#   -77,
#   -76,
#   -77,
#   -77,
#   -77,
#   -72,
#   -70,
#   -70,
#   -65,
#   -57,
#   -43,
#   -39,
#   -27,
#   -32,
#   -17,
#   5,
#   9,
#   31,
#   31,
#   31,
#   32,
#   42,
#   43,
#   50,
#   52,
#   49,
#   63,
#   68,
#   66,
#   73,
#   68,
#   66,
#   57,
#   60,
#   52,
#   55,
#   57,
#   61,
#   66,
#   66,
#   61,
#   52,
#   38,
#   31,
#   -3,
#   -18,
#   -42,
#   -47,
#   -51,
#   -62,
#   -64,
#   -71,
#   -73,
#   -76,
#   -76,
#   -78,
#   -76,
#   -79,
#   -85,
#   -79,
#   -85,
#   -88,
#   -74,
#   -74,
#   -46,
#   -35,
#   -24,
#   -24,
#   -18,
#   -17,
#   -17,
#   -13,
#   -12,
#   -7,
#   -2,
#   -1,
#   -8,
#   -11,
#   -10,
#   -16,
#   -21,
#   -38,
#   -38,
#   -57,
#   -73,
#   -74,
#   -66,
#   -67,
#   -61,
#   -62,
#   -63,
#   -61,
#   -81,
#   -82,
#   -81,
#   -72,
#   -74,
#   -66,
#   -61,
#   -56,
#   -25,
#   -6,
#   -3,
#   26,
#   59,
#   70,
#   61,
#   62,
#   59,
#   64,
#   71,
#   70,
#   91,
#   99,
#   91,
#   82,
#   94,
#   89,
#   84,
#   84,
#   65,
#   71,
#   96,
#   100,
#   92,
#   87,
#   87,
#   90,
#   88,
#   87,
#   85,
#   85,
#   85,
#   84,
#   95,
#   99,
#   96,
#   96,
#   96,
#   93,
#   91,
#   85,
#   57,
#   48,
#   41,
#   47,
#   44,
#   41,
#   37,
#   36,
#   33,
#   36,
#   36,
#   31,
#   23,
#   19,
#   16,
#   21,
#   25,
#   23,
#   27,
#   30,
#   30,
#   27,
#   34,
#   35,
#   40,
#   42,
#   57,
#   65,
#   60,
#   66,
#   73,
#   72,
#   72,
#   84,
#   98,
#   111,
#   107,
#   106,
#   111,
#   113,
#   118,
#   118,
#   113,
#   104,
#   97,
#   100,
#   99,
#   89,
#   89,
#   83,
#   76,
#   88,
#   102,
#   95,
#   94,
#   81,
#   91,
#   101,
#   91,
#   91,
#   87,
#   90,
#   105,
#   117,
#   127,
#   122,
#   133,
#   155,
#   175,
#   204,
#   213,
#   207,
#   212,
#   216,
#   202,
#   202,
#   197,
#   198,
#   210,
#   230,
#   267,
#   280,
#   282,
#   274,
#   300,
#   309,
#   295,
#   272,
#   257,
#   225,
#   217,
#   211,
#   190,
#   179,
#   183,
#   178,
#   172,
#   179,
#   170,
#   163,
#   153,
#   135,
#   118,
#   111,
#   84,
#   83,
#   77,
#   83,
#   88,
#   89,
#   88,
#   88,
#   96,
#   103,
#   98,
#   103,
#   108,
#   95,
#   100,
#   77,
#   52,
#   54,
#   55,
#   57,
#   53,
#   47,
#   43,
#   44,
#   44,
#   43,
#   59,
#   59,
#   53,
#   48,
#   51,
#   47,
#   43,
#   39,
#   34,
#   39,
#   35,
#   38,
#   55,
#   53,
#   57,
#   55,
#   53,
#   46,
#   41,
#   41,
#   10,
#   -6,
#   -14,
#   -23,
#   -27,
#   -37,
#   -38,
#   -37,
#   -41,
#   -41,
#   -47,
#   -85,
#   -103,
#   -118,
#   -139,
#   -141,
#   -139,
#   -151,
#   -147,
#   -152,
#   -167,
#   -152,
#   -148,
#   -149,
#   -148,
#   -139,
#   -142,
#   -139,
#   -133,
#   -142,
#   -130,
#   -99,
#   -97,
#   -82,
#   -64,
#   -57,
#   -43,
#   -31,
#   -28,
#   -23,
#   23,
#   24,
#   32,
#   59,
#   58,
#   55,
#   59,
#   51,
#   22,
#   31,
#   26,
#   28,
#   26,
#   22,
#   21,
#   0,
#   -22,
#   -26,
#   -50,
#   -50,
#   -78,
#   -105,
#   -109,
#   -144,
#   -154,
#   -160,
#   -165,
#   -161,
#   -134,
#   -134,
#   -144,
#   -186,
#   -191,
#   -201,
#   -206,
#   -190,
#   -182,
#   -183,
#   -183,
#   -187,
#   -179,
#   -155,
#   -155,
#   -137,
#   -125,
#   -121,
#   -120,
#   -123,
#   -127,
#   -127,
#   -123,
#   -86,
#   -85,
#   -69,
#   -74,
#   -74,
#   -74,
#   -72,
#   -55,
#   -51],
#  1: [0,
#   0,
#   0,
#   0,
#   -2,
#   -2,
#   -4,
#   -4,
#   -6,
#   -6,
#   -8,
#   -8,
#   -8,
#   -8,
#   -27,
#   -27,
#   -27,
#   -21,
#   -18,
#   2,
#   2,
#   2,
#   4,
#   4,
#   10,
#   12,
#   20,
#   21,
#   23,
#   23,
#   29,
#   29,
#   29,
#   27,
#   46,
#   46,
#   45,
#   39,
#   36,
#   16,
#   14,
#   14,
#   9,
#   4,
#   0,
#   -2,
#   -9,
#   -10,
#   8,
#   26,
#   19,
#   23,
#   24,
#   25,
#   25,
#   25,
#   26,
#   27,
#   27,
#   27,
#   30,
#   30,
#   35,
#   40,
#   41,
#   41,
#   40,
#   40,
#   27,
#   5,
#   8,
#   5,
#   4,
#   5,
#   5,
#   5,
#   5,
#   6,
#   6,
#   6,
#   10,
#   10,
#   12,
#   12,
#   11,
#   10,
#   12,
#   10,
#   -6,
#   -4,
#   -4,
#   -6,
#   -6,
#   -6,
#   -11,
#   -11,
#   -11,
#   -22,
#   -22,
#   -22,
#   -30,
#   -32,
#   -38,
#   -50,
#   -75,
#   -74,
#   -70,
#   -66,
#   -52,
#   -49,
#   -49,
#   -48,
#   -48,
#   -47,
#   -40,
#   -39,
#   -39,
#   -28,
#   -27,
#   -23,
#   0,
#   5,
#   3,
#   15,
#   43,
#   43,
#   39,
#   39,
#   36,
#   35,
#   45,
#   50,
#   55,
#   59,
#   80,
#   93,
#   99,
#   97,
#   96,
#   92,
#   72,
#   72,
#   80,
#   81,
#   78,
#   75,
#   75,
#   69,
#   69,
#   65,
#   50,
#   7,
#   -1,
#   -35,
#   -77,
#   -100,
#   -106,
#   -106,
#   -107,
#   -107,
#   -108,
#   -111,
#   -116,
#   -117,
#   -125,
#   -120,
#   -120,
#   -112,
#   -112,
#   -106,
#   -102,
#   -64,
#   -61,
#   -32,
#   -12,
#   -3,
#   -7,
#   -7,
#   -6,
#   -6,
#   -6,
#   -8,
#   -7,
#   -9,
#   -7,
#   -9,
#   -9,
#   -18,
#   -23,
#   -25,
#   -27,
#   -29,
#   -29,
#   -29,
#   -30,
#   -30,
#   -26,
#   -30,
#   -35,
#   -35,
#   -34,
#   -37,
#   -59,
#   -57,
#   -61,
#   -80,
#   -80,
#   -75,
#   -75,
#   -80,
#   -82,
#   -94,
#   -99,
#   -99,
#   -99,
#   -99,
#   -99,
#   -100,
#   -100,
#   -100,
#   -100,
#   -95,
#   -73,
#   -73,
#   -68,
#   -49,
#   -59,
#   -59,
#   -59,
#   -63,
#   -63,
#   -54,
#   -54,
#   -64,
#   -69,
#   -69,
#   -69,
#   -71,
#   -96,
#   -105,
#   -110,
#   -115,
#   -133,
#   -138,
#   -133,
#   -133,
#   -123,
#   -123,
#   -123,
#   -127,
#   -123,
#   -134,
#   -129,
#   -129,
#   -124,
#   -134,
#   -155,
#   -148,
#   -118,
#   -109,
#   -104,
#   -106,
#   -106,
#   -101,
#   -106,
#   -111,
#   -116,
#   -116,
#   -111,
#   -103,
#   -125,
#   -109,
#   -113,
#   -107,
#   -107,
#   -98,
#   -77,
#   -78,
#   -78,
#   -78,
#   -78,
#   -71,
#   -55,
#   -55,
#   -50,
#   -45,
#   -40,
#   -44,
#   -46,
#   -45,
#   -24,
#   -28,
#   -24,
#   -20,
#   -22,
#   -26,
#   -26,
#   -25,
#   -25,
#   -25,
#   -25,
#   -24,
#   -16,
#   -16,
#   -21,
#   -21,
#   -21,
#   -17,
#   -15,
#   -11,
#   -9,
#   -2,
#   -2,
#   -4,
#   -2,
#   -3,
#   -1,
#   -1,
#   -1,
#   -1,
#   3,
#   5,
#   3,
#   7,
#   12,
#   12,
#   14,
#   14,
#   14,
#   12,
#   15,
#   16,
#   16,
#   25,
#   21,
#   29,
#   29,
#   29,
#   33,
#   33,
#   22,
#   12,
#   8,
#   7,
#   7,
#   7,
#   7,
#   27,
#   42,
#   44,
#   45,
#   44,
#   44,
#   37,
#   41,
#   43,
#   46,
#   47,
#   43,
#   43,
#   65,
#   70,
#   73,
#   70,
#   74,
#   78,
#   76,
#   60,
#   45,
#   45,
#   39,
#   36,
#   36,
#   32,
#   32,
#   24,
#   13,
#   10,
#   10,
#   7,
#   -24,
#   -20,
#   -27,
#   -27,
#   -31,
#   -39,
#   -39,
#   -43,
#   -43,
#   -45,
#   -44,
#   -44,
#   -45,
#   -15,
#   -17,
#   -16,
#   -10,
#   -5,
#   -5,
#   -2,
#   14,
#   15,
#   16,
#   2,
#   2,
#   6,
#   9,
#   8,
#   6,
#   -3,
#   -7,
#   -12,
#   -24,
#   -49,
#   -50,
#   -62,
#   -92,
#   -108,
#   -138,
#   -143,
#   -185,
#   -203,
#   -205,
#   -195,
#   -195,
#   -214,
#   -217,
#   -216,
#   -233,
#   -222,
#   -217,
#   -210,
#   -195,
#   -196,
#   -190,
#   -179,
#   -149,
#   -127,
#   -97,
#   -70,
#   -28,
#   7,
#   30,
#   34,
#   34,
#   53,
#   52,
#   51,
#   71,
#   70,
#   70,
#   68,
#   65,
#   65,
#   53,
#   57,
#   13,
#   5,
#   5,
#   -28,
#   -31,
#   -63,
#   -86,
#   -126,
#   -130,
#   -130,
#   -134,
#   -133,
#   -134,
#   -133,
#   -133,
#   -138,
#   -147,
#   -164,
#   -155,
#   -169,
#   -155,
#   -177,
#   -180,
#   -182,
#   -194,
#   -192,
#   -192,
#   -171,
#   -181,
#   -209,
#   -204,
#   -226,
#   -236,
#   -236,
#   -257,
#   -264,
#   -286,
#   -274,
#   -283,
#   -297,
#   -267,
#   -246,
#   -243,
#   -254],
#  2: [0,
#   0,
#   2,
#   7,
#   2,
#   -2,
#   -2,
#   -2,
#   -4,
#   -4,
#   -4,
#   -4,
#   -21,
#   -30,
#   -30,
#   -31,
#   -31,
#   -23,
#   -19,
#   -13,
#   -6,
#   -2,
#   -2,
#   -7,
#   -2,
#   9,
#   12,
#   13,
#   16,
#   15,
#   18,
#   18,
#   35,
#   44,
#   44,
#   50,
#   41,
#   32,
#   28,
#   22,
#   16,
#   17,
#   14,
#   12,
#   13,
#   13,
#   13,
#   12,
#   22,
#   20,
#   20,
#   15,
#   16,
#   24,
#   28,
#   23,
#   33,
#   32,
#   32,
#   32,
#   32,
#   31,
#   31,
#   35,
#   39,
#   44,
#   41,
#   36,
#   20,
#   23,
#   20,
#   24,
#   18,
#   8,
#   9,
#   6,
#   9,
#   8,
#   10,
#   10,
#   10,
#   8,
#   15,
#   10,
#   5,
#   -7,
#   -7,
#   -5,
#   -8,
#   -8,
#   -5,
#   -3,
#   0,
#   -1,
#   -4,
#   1,
#   -3,
#   2,
#   6,
#   2,
#   0,
#   -8,
#   -17,
#   -18,
#   -21,
#   -18,
#   -17,
#   -14,
#   -4,
#   -4,
#   -8,
#   -2,
#   -2,
#   3,
#   2,
#   -2,
#   0,
#   -7,
#   -13,
#   -12,
#   -8,
#   7,
#   10,
#   9,
#   8,
#   5,
#   9,
#   12,
#   10,
#   10,
#   11,
#   14,
#   35,
#   78,
#   80,
#   100,
#   141,
#   146,
#   150,
#   148,
#   145,
#   124,
#   119,
#   124,
#   95,
#   85,
#   78,
#   67,
#   62,
#   48,
#   30,
#   20,
#   3,
#   -47,
#   -50,
#   -65,
#   -105,
#   -92,
#   -95,
#   -89,
#   -89,
#   -74,
#   -62,
#   -67,
#   -34,
#   -22,
#   -20,
#   -12,
#   -10,
#   2,
#   25,
#   31,
#   30,
#   39,
#   37,
#   34,
#   33,
#   21,
#   20,
#   18,
#   14,
#   13,
#   6,
#   6,
#   6,
#   4,
#   0,
#   3,
#   0,
#   0,
#   -7,
#   -13,
#   -13,
#   -20,
#   -14,
#   -19,
#   -21,
#   -19,
#   -14,
#   -27,
#   -22,
#   -28,
#   -33,
#   -34,
#   -34,
#   -47,
#   -43,
#   -46,
#   -32,
#   -30,
#   -38,
#   -36,
#   -49,
#   -45,
#   -45,
#   -40,
#   -41,
#   -44,
#   -54,
#   -47,
#   -48,
#   -43,
#   -43,
#   -43,
#   -50,
#   -37,
#   -38,
#   -42,
#   -61,
#   -70,
#   -56,
#   -63,
#   -50,
#   -62,
#   -110,
#   -121,
#   -120,
#   -120,
#   -120,
#   -108,
#   -108,
#   -109,
#   -104,
#   -98,
#   -101,
#   -101,
#   -107,
#   -103,
#   -92,
#   -87,
#   -91,
#   -84,
#   -94,
#   -98,
#   -53,
#   -47,
#   -61,
#   -61,
#   -57,
#   -58,
#   -60,
#   -65,
#   -77,
#   -88,
#   -86,
#   -86,
#   -81,
#   -83,
#   -95,
#   -112,
#   -112,
#   -120,
#   -139,
#   -135,
#   -141,
#   -137,
#   -125,
#   -127,
#   -130,
#   -130,
#   -127,
#   -124,
#   -116,
#   -107,
#   -94,
#   -98,
#   -95,
#   -95,
#   -96,
#   -75,
#   -75,
#   -73,
#   -46,
#   -35,
#   -30,
#   -24,
#   -22,
#   -23,
#   -20,
#   -21,
#   -27,
#   -26,
#   -27,
#   -21,
#   -24,
#   -20,
#   -21,
#   -12,
#   3,
#   -3,
#   -5,
#   -5,
#   -4,
#   3,
#   -2,
#   -7,
#   -2,
#   1,
#   5,
#   5,
#   13,
#   11,
#   14,
#   13,
#   6,
#   3,
#   -1,
#   -5,
#   -7,
#   3,
#   11,
#   15,
#   27,
#   43,
#   48,
#   49,
#   55,
#   59,
#   57,
#   47,
#   44,
#   45,
#   47,
#   50,
#   57,
#   60,
#   64,
#   70,
#   70,
#   64,
#   55,
#   46,
#   34,
#   11,
#   18,
#   23,
#   41,
#   36,
#   32,
#   38,
#   38,
#   40,
#   44,
#   38,
#   34,
#   39,
#   39,
#   30,
#   45,
#   66,
#   78,
#   88,
#   89,
#   89,
#   81,
#   75,
#   47,
#   53,
#   56,
#   57,
#   65,
#   65,
#   61,
#   65,
#   68,
#   67,
#   67,
#   65,
#   50,
#   31,
#   22,
#   25,
#   30,
#   32,
#   31,
#   31,
#   30,
#   14,
#   8,
#   6,
#   -7,
#   -4,
#   -4,
#   -14,
#   -34,
#   -47,
#   -47,
#   -46,
#   -46,
#   -49,
#   -47,
#   -55,
#   -71,
#   -81,
#   -101,
#   -101,
#   -105,
#   -94,
#   -94,
#   -115,
#   -110,
#   -115,
#   -110,
#   -117,
#   -132,
#   -119,
#   -119,
#   -111,
#   -119,
#   -116,
#   -109,
#   -105,
#   -95,
#   -87,
#   -65,
#   -70,
#   -64,
#   -65,
#   -54,
#   -31,
#   -33,
#   -31,
#   -33,
#   -22,
#   12,
#   3,
#   3,
#   -4,
#   4,
#   6,
#   -13,
#   -28,
#   -30,
#   -31,
#   -47,
#   -47,
#   -62,
#   -82,
#   -96,
#   -116,
#   -117,
#   -128,
#   -163,
#   -179,
#   -183,
#   -178,
#   -173,
#   -171,
#   -176,
#   -185,
#   -194,
#   -194,
#   -237,
#   -261,
#   -277,
#   -273,
#   -265,
#   -245,
#   -277,
#   -267,
#   -261,
#   -252,
#   -219,
#   -222,
#   -248,
#   -253,
#   -279,
#   -280,
#   -294,
#   -297,
#   -278,
#   -284,
#   -255,
#   -264,
#   -226,
#   -230,
#   -236,
#   -242,
#   -204,
#   -202]}

# %%
from AgentBasedModel.model.plots import plot_feature

# %%
plot_feature(trade_volume_imbalance)
plot_feature(bid_ask_spread)
plot_feature(bid_ask_volume_imbalance)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.figure(figsize = (14, 6))
sns.histplot(pd.DataFrame(trade_volume_imbalance.compile_feature()), bins = 15, multiple="dodge", shrink=.8);

# %%
fig.figsize
# Out:
# (20, 10)

# %%
(i + 1) % 3
# Out:
# 1

# %%
chosen_exchanges = info.exchanges
features = [bid_ask_spread, bid_ask_volume_imbalance, trade_volume_imbalance]
fig, axs = plt.subplots(3, 3, figsize=(4 * len(features), 3 * len(features)))
fig.figsize = (20, 10)
for exchange in chosen_exchanges:
    for i in range(len(features)):
        for j in range(len(features)):
            if i == j:
                axs[i, i].hist(features[i].compile_feature()[exchange], bins = 10)
            else: 
                axs[i, j].scatter(features[i].compile_feature()[exchange], (features[j].compile_feature()[exchange]))
